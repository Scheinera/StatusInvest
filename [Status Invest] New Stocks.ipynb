# %% [markdown]
# # New Stocks

# %% [markdown]
# ## Indicadores consolidados - Empresas

# %%
import statistics
import pandas as pd
import numpy as np
import json
import requests
from bs4 import BeautifulSoup
import os
from pathlib import Path

# %% [markdown]
# ## Dividend Yield - DY

# %%
tickets = pd.read_csv('ticker.csv')
tick_list = tickets['tickers'].tolist()
len(tick_list)
# Out:
# 620

# %%
# dicionario com todas as ações por linha a serem substituidas
index_stocks = []
index_tickers = {}
for i, v in zip((range(len(tick_list))), tick_list):
    index_tickers[i] = v
    index_stocks.append(index_tickers)
#index_tickers


url = 'https://statusinvest.com.br/acoes/busca-avancada'

dys = []

url = 'https://statusinvest.com.br/acoes/'

for i, v in zip(tick_list, (range(len(tick_list)))):
    print(f'{v}.{i}') 

    headers = {
        'authority': 'statusinvest.com.br',
        'sec-ch-ua': '\"Google Chrome\";v=\"116\", \"Chromium\";v=\"116\", \";Not A Brand\";v=\"99\"',
        'accept': '*/*',
        'x-requested-with': 'XMLHttpRequest',
        'sec-ch-ua-mobile': '?0',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36',
        'content-type': 'application/x-www-form-urlencoded; charset=UTF-8',
        'origin': 'https://statusinvest.com.br',
        'sec-fetch-site': 'same-origin',
        'sec-fetch-mode': 'cors',
        'sec-fetch-dest': 'empty',
        'referer': url + str(i),
        'accept-language': 'pt-BR,pt;q=0.9,en-US;q=0.8,en;q=0.7',
        'cookie': '_adasys=e2299e4d-38b0-48c7-91be-a844fb91e62c; _ga=GA1.3.1768435062.1608297004; G_ENABLED_IDPS=google; __cfduid=d96cf593e372b319fd9ac85a0385fd3971614276176; denakop_freq={}; _gid=GA1.3.490929924.1615153324; __cf_bm=ccb5439cbc002734ed38f28e7c99677ec0b5afff-1615325452-1800-AWbw2mlOXKHt6BZ0dybIWT1O8Z4S9u6Mv7pm7/qkTNvQPFa+jTjP1n06mQmPXqmE938CAjZonuuP2B6noCkuoBpP5ouTIc/MWeUoxtuhdKfJ05v24zpwzU/CpAosevhANA==; _gat_gtag_UA_142136095_1=1',
    }   

    data = {
        'ticker': str(i),
        'time': '5'
    }

    response = requests.post('https://statusinvest.com.br/acao/indicatorhistorical', headers=headers, data=data)

    
    try:
        r = response.json()
    except json.JSONDecodeError as e:
        print(f"Error decoding JSON: {e}")
        exit(1)
    

    # Coletando informações para DataFrame
    dy = {}
    
    
    c = requests.get(url + str(i)).content
    soup = BeautifulSoup(c)


       ### INDICADORES DE VALUATION ###

    try:    
        dy['DY'] = r['data'][0]['ranks'][0]['value_F']
    except:
        dy['DY'] = np.NaN
    try:    
        dy['2022'] = r['data'][0]['ranks'][1]['value_F']
    except:
        dy['2022'] = np.NaN
    try:    
        dy['2021'] = r['data'][0]['ranks'][2]['value_F']
    except:
        dy['2021'] = np.NaN
    try:    
        dy['2020'] = r['data'][0]['ranks'][3]['value_F']
    except:
        dy['2020'] = np.NaN
    try:    
        dy['2019'] = r['data'][0]['ranks'][4]['value_F']
    except:
        dy['2019'] = np.NaN
    try:    
        dy['2018'] = r['data'][0]['ranks'][5]['value_F']
    except:
        dy['2018'] = np.NaN
    try:    
        dy['2017'] = r['data'][0]['ranks'][6]['value_F']
    except:
        dy['2017'] = np.NaN
    try:    
        dy['2016'] = r['data'][0]['ranks'][7]['value_F']
    except:
        dy['2016'] = np.NaN    
    try:    
        dy['2015'] = r['data'][0]['ranks'][8]['value_F']
    except:
        dy['2015'] = np.NaN
    try:    
        dy['2014'] = r['data'][0]['ranks'][9]['value_F']
    except:
        dy['2014'] = np.NaN
    try:    
        dy['2013'] = r['data'][0]['ranks'][10]['value_F']
    except:
        dy['2013'] = np.NaN
    try:    
        dy['2012'] = r['data'][0]['ranks'][11]['value_F']
    except:
        dy['2012'] = np.NaN    
    try:    
        dy['2011'] = r['data'][0]['ranks'][12]['value_F']
    except:
        dy['2011'] = np.NaN


# Adicionando resultado a lista de cards
    dys.append(dy)
# Out:
# 0.AALR3
# 1.ABCB4
# 2.ABEV3
# 3.ADHM3
# 4.AERI3
# 5.AESB3
# 6.AFLT3
# 7.AGRO3
# 8.AGXY3
# 9.AHEB3
# 10.AHEB5
# 11.AHEB6
# 12.ALLD3
# 13.ALPA3
# 14.ALPA4
# 15.ALPK3
# 16.ALSC3
# 17.ALSO3
# 18.ALUP11
# 19.ALUP3
# 20.ALUP4
# 21.AMAR3
# 22.AMBP3
# 23.AMER3
# 24.ANDG3B
# 25.ANDG4B
# 26.ANIM3
# 27.APER3
# 28.APTI3
# 29.APTI4
# 30.ARML3
# 31.ARZZ3
# 32.ASAI3
# 33.ATMP3
# 34.ATOM3
# 35.AURA33
# 36.AURE3
# 37.AVLL3
# 38.AZEV3
# 39.AZEV4
# 40.AZUL4
# 41.B3SA3
# 42.BAHI3
# 43.BALM3
# 44.BALM4
# 45.BAUH4
# 46.BAZA3
# 47.BBAS3
# 48.BBDC3
# 49.BBDC4
# 50.BBML3
# 51.BBSE3
# 52.BDLL3
# 53.BDLL4
# 54.BEEF11
# 55.BEEF3
# 56.BEES3
# 57.BEES4
# 58.BFRE11
# 59.BFRE12
# 60.BGIP3
# 61.BGIP4
# 62.BIDI11
# 63.BIDI3
# 64.BIDI4
# 65.BIOM3
# 66.BLAU3
# 67.BLUT3
# 68.BLUT4
# 69.BMEB3
# 70.BMEB4
# 71.BMGB4
# 72.BMIN3
# 73.BMIN4
# 74.BMKS3
# 75.BMOB3
# 76.BNBR3
# 77.BOAS3
# 78.BOBR3
# 79.BOBR4
# 80.BPAC11
# 81.BPAC3
# 82.BPAC5
# 83.BPAN4
# 84.BPAR3
# 85.BPAT33
# 86.BPHA3
# 87.BRAP3
# 88.BRAP4
# 89.BRBI11
# 90.BRBI3
# 91.BRBI4
# 92.BRFS3
# 93.BRGE11
# 94.BRGE12
# 95.BRGE3
# 96.BRGE5
# 97.BRGE6
# 98.BRGE7
# 99.BRGE8
# 100.BRIN3
# 101.BRIT3
# 102.BRIV3
# 103.BRIV4
# 104.BRKM3
# 105.BRKM5
# 106.BRKM6
# 107.BRML3
# 108.BRPR3
# 109.BRQB3
# 110.BRSR3
# 111.BRSR5
# 112.BRSR6
# 113.BSEV3
# 114.BSLI3
# 115.BSLI4
# 116.BTTL4
# 117.CALI3
# 118.CALI4
# 119.CAMB3
# 120.CAMB4
# 121.CAML3
# 122.CASH3
# 123.CASN3
# 124.CASN4
# 125.CATA3
# 126.CATA4
# 127.CBAV3
# 128.CBEE3
# 129.CCRO3
# 130.CCXC3
# 131.CEAB3
# 132.CEBR3
# 133.CEBR5
# 134.CEBR6
# 135.CEDO3
# 136.CEDO4
# 137.CEEB3
# 138.CEEB5
# 139.CEEB6
# 140.CEED3
# 141.CEED4
# 142.CEGR3
# 143.CEPE3
# 144.CEPE5
# 145.CEPE6
# 146.CESP3
# 147.CESP5
# 148.CESP6
# 149.CGAS3
# 150.CGAS5
# 151.CGRA3
# 152.CGRA4
# 153.CIEL3
# 154.CLSA3
# 155.CLSC3
# 156.CLSC4
# 157.CMIG3
# 158.CMIG4
# 159.CMIN3
# 160.CMSA3
# 161.CMSA4
# 162.CNSY3
# 163.COCE3
# 164.COCE5
# 165.COCE6
# 166.COGN3
# 167.CORR3
# 168.CORR4
# 169.CPFE3
# 170.CPLE11
# 171.CPLE3
# 172.CPLE5
# 173.CPLE6
# 174.CPRE3
# 175.CREM3
# 176.CRFB3
# 177.CRIV3
# 178.CRIV4
# 179.CRPG3
# 180.CRPG5
# 181.CRPG6
# 182.CSAB3
# 183.CSAB4
# 184.CSAN3
# 185.CSED3
# 186.CSMG3
# 187.CSNA3
# 188.CSRN3
# 189.CSRN5
# 190.CSRN6
# 191.CSUD3
# 192.CTCA3
# 193.CTKA3
# 194.CTKA4
# 195.CTNM3
# 196.CTNM4
# 197.CTSA3
# 198.CTSA4
# 199.CTSA8
# 200.CURY3
# 201.CVCB3
# 202.CXSE3
# 203.CYRE3
# 204.DASA3
# 205.DESK3
# 206.DEXP3
# 207.DEXP4
# 208.DIRR3
# 209.DMMO11
# 210.DMMO3
# 211.DMVF3
# 212.DOHL3
# 213.DOHL4
# 214.DOTZ3
# 215.DTCY3
# 216.DTCY4
# 217.DXCO3
# 218.EALT3
# 219.EALT4
# 220.ECOR3
# 221.ECPR3
# 222.ECPR4
# 223.EEEL3
# 224.EEEL4
# 225.EGIE3
# 226.EKTR3
# 227.EKTR4
# 228.ELEK3
# 229.ELEK4
# 230.ELET3
# 231.ELET5
# 232.ELET6
# 233.ELMD3
# 234.ELPL3
# 235.EMAE3
# 236.EMAE4
# 237.EMBR3
# 238.ENAT3
# 239.ENBR3
# 240.ENEV3
# 241.ENGI11
# 242.ENGI3
# 243.ENGI4
# 244.ENJU3
# 245.ENMA3B
# 246.ENMA6B
# 247.ENMT3
# 248.ENMT4
# 249.EPAR3
# 250.EQPA3
# 251.EQPA5
# 252.EQPA6
# 253.EQPA7
# 254.EQTL3
# 255.ESPA3
# 256.ESTR3
# 257.ESTR4
# 258.ETER3
# 259.EUCA3
# 260.EUCA4
# 261.EVEN3
# 262.EZTC3
# 263.FBMC3
# 264.FBMC4
# 265.FESA3
# 266.FESA4
# 267.FHER3
# 268.FIBR3
# 269.FIEI3
# 270.FIGE3
# 271.FIGE4
# 272.FIQE3
# 273.FLEX3
# 274.FLRY3
# 275.FNCN3
# 276.FRAS3
# 277.FRIO3
# 278.FRTA3
# 279.FTRT3B
# 280.G2DI33
# 281.GBIO33
# 282.GEPA3
# 283.GEPA4
# 284.GETT11
# 285.GETT3
# 286.GETT4
# 287.GFSA3
# 288.GGBR3
# 289.GGBR4
# 290.GGPS3
# 291.GMAT3
# 292.GNDI3
# 293.GOAU3
# 294.GOAU4
# 295.GOLL4
# 296.GPAR3
# 297.GPIV33
# 298.GRAO3
# 299.GRND3
# 300.GSHP3
# 301.GUAR3
# 302.GUAR4
# 303.HAGA3
# 304.HAGA4
# 305.HAPV3
# 306.HBOR3
# 307.HBRE3
# 308.HBSA3
# 309.HBTS5
# 310.HETA3
# 311.HETA4
# 312.HGTX3
# 313.HOOT3
# 314.HOOT4
# 315.HYPE3
# 316.IDVL3
# 317.IDVL4
# 318.IFCM3
# 319.IGBR3
# 320.IGSN3
# 321.IGTA3
# 322.IGTI11
# 323.IGTI3
# 324.IGTI4
# 325.INEP3
# 326.INEP4
# 327.INNT3
# 328.INTB3
# 329.IRBR3
# 330.ITEC3
# 331.ITSA3
# 332.ITSA4
# 333.ITUB3
# 334.ITUB4
# 335.JALL3
# 336.JBSS3
# 337.JFEN3
# 338.JHSF3
# 339.JOPA3
# 340.JOPA4
# 341.JSLG3
# 342.KEPL3
# 343.KLBN11
# 344.KLBN3
# 345.KLBN4
# 346.KRSA3
# 347.LAME3
# 348.LAME4
# 349.LAND3
# 350.LAVV3
# 351.LCAM3
# 352.LEVE3
# 353.LHER3
# 354.LHER4
# 355.LIGT3
# 356.LINX3
# 357.LIPR3
# 358.LJQQ3
# 359.LOGG3
# 360.LOGN3
# 361.LPSB3
# 362.LREN3
# 363.LTEL3B
# 364.LUPA3
# 365.LUXM3
# 366.LUXM4
# 367.LVTC3
# 368.LWSA3
# 369.MAGG3
# 370.MAPT3
# 371.MAPT4
# 372.MATD3
# 373.MBLY3
# 374.MDIA3
# 375.MDNE3
# 376.MEAL3
# 377.MEGA3
# 378.MELK3
# 379.MERC3
# 380.MERC4
# 381.MGEL3
# 382.MGEL4
# 383.MGLU3
# 384.MILS3
# 385.MLAS3
# 386.MMAQ3
# 387.MMAQ4
# 388.MMXM3
# 389.MNDL3
# 390.MNPR3
# 391.MOAR3
# 392.MODL11
# 393.MODL3
# 394.MODL4
# 395.MOSI3
# 396.MOVI3
# 397.MPLU3
# 398.MRFG3
# 399.MRSA3B
# 400.MRSA5B
# 401.MRSA6B
# 402.MRVE3
# 403.MSPA3
# 404.MSPA4
# 405.MSRO3
# 406.MTIG3
# 407.MTIG4
# 408.MTRE3
# 409.MTSA3
# 410.MTSA4
# 411.MULT3
# 412.MWET3
# 413.MWET4
# 414.MYPK3
# 415.NAFG3
# 416.NAFG4
# 417.NEMO3
# 418.NEMO5
# 419.NEMO6
# 420.NEOE3
# 421.NEXP3
# 422.NGRD3
# 423.NINJ3
# 424.NORD3
# 425.NRTQ3
# 426.NTCO3
# 427.NUTR3
# 428.ODER4
# 429.ODPV3
# 430.OFSA3
# 431.OGXP3
# 432.OIBR3
# 433.OIBR4
# 434.OMGE3
# 435.ONCO3
# 436.OPCT3
# 437.ORVR3
# 438.OSXB3
# 439.PARD3
# 440.PATI3
# 441.PATI4
# 442.PCAR3
# 443.PCAR4
# 444.PDGR3
# 445.PDTC3
# 446.PEAB3
# 447.PEAB4
# 448.PETR3
# 449.PETR4
# 450.PETZ3
# 451.PFRM3
# 452.PGMN3
# 453.PINE3
# 454.PINE4
# 455.PLAS3
# 456.PLPL3
# 457.PMAM3
# 458.PNVL3
# 459.PNVL4
# 460.POMO3
# 461.POMO4
# 462.PORT3
# 463.POSI3
# 464.POWE3
# 465.PPAR3
# 466.PPLA11
# 467.PRIO3
# 468.PRNR3
# 469.PSSA3
# 470.PTBL3
# 471.PTCA11
# 472.PTCA3
# 473.PTNT3
# 474.PTNT4
# 475.QGEP3
# 476.QUAL3
# 477.QUSW3
# 478.QVQP3B
# 479.RADL3
# 480.RAIL3
# 481.RAIZ4
# 482.RANI3
# 483.RANI4
# 484.RAPT3
# 485.RAPT4
# 486.RCSL3
# 487.RCSL4
# 488.RDNI3
# 489.RDOR3
# 490.RECV3
# 491.REDE3
# 492.RENT3
# 493.RLOG3
# 494.RNEW11
# 495.RNEW3
# 496.RNEW4
# 497.ROMI3
# 498.RPAD3
# 499.RPAD5
# 500.RPAD6
# 501.RPMG3
# 502.RRRP3
# 503.RSID3
# 504.RSUL3
# 505.RSUL4
# 506.SANB11
# 507.SANB3
# 508.SANB4
# 509.SAPR11
# 510.SAPR3
# 511.SAPR4
# 512.SBFG3
# 513.SBSP3
# 514.SCAR3
# 515.SEDU3
# 516.SEER3
# 517.SEQL3
# 518.SGPS3
# 519.SHOW3
# 520.SHUL3
# 521.SHUL4
# 522.SIMH3
# 523.SLCE3
# 524.SLED3
# 525.SLED4
# 526.SMFT3
# 527.SMLS3
# 528.SMTO3
# 529.SNSY3
# 530.SNSY5
# 531.SNSY6
# 532.SOJA3
# 533.SOMA3
# 534.SOND3
# 535.SOND5
# 536.SOND6
# 537.SPRI3
# 538.SPRI5
# 539.SPRI6
# 540.SPRT3B
# 541.SQIA3
# 542.STBP3
# 543.STKF3
# 544.STTR3
# 545.SULA11
# 546.SULA3
# 547.SULA4
# 548.SUZB3
# 549.SYNE3
# 550.TAEE11
# 551.TAEE3
# 552.TAEE4
# 553.TASA3
# 554.TASA4
# 555.TCNO3
# 556.TCNO4
# 557.TCSA3
# 558.TECN3
# 559.TEKA3
# 560.TEKA4
# 561.TELB3
# 562.TELB4
# 563.TEND3
# 564.TESA3
# 565.TFCO4
# 566.TGMA3
# 567.TIET11
# 568.TIET3
# 569.TIET4
# 570.TIMS3
# 571.TKNO3
# 572.TKNO4
# 573.TOTS3
# 574.TOYB3
# 575.TOYB4
# 576.TPIS3
# 577.TRAD3
# 578.TRIS3
# 579.TRPL3
# 580.TRPL4
# 581.TRPN3
# 582.TTEN3
# 583.TUPY3
# 584.TXRX3
# 585.TXRX4
# 586.UCAS3
# 587.UGPA3
# 588.UNIP3
# 589.UNIP5
# 590.UNIP6
# 591.USIM3
# 592.USIM5
# 593.USIM6
# 594.VALE3
# 595.VAMO3
# 596.VBBR3
# 597.VIIA3
# 598.VITT3
# 599.VIVA3
# 600.VIVR3
# 601.VIVT3
# 602.VIVT4
# 603.VLID3
# 604.VSPT3
# 605.VSPT4
# 606.VSTE3
# 607.VULC3
# 608.VVAR11
# 609.VVAR4
# 610.VVEO3
# 611.WEGE3
# 612.WEST3
# 613.WHRL3
# 614.WHRL4
# 615.WIZC3
# 616.WLMM3
# 617.WLMM4
# 618.YDUQ3
# 619.ZAMP3

# %%
# Criando um DataFrame com os resultados
dividend = pd.DataFrame(dys)
dividend.rename(index = index_tickers, inplace = True)
dividend = dividend.replace('-%', '')
dividend = dividend.replace('-', '')

dividend['DY'] = (dividend['DY']).str.rstrip('%')
dividend['2022'] = (dividend['2022']).str.rstrip('%')
dividend['2021'] = (dividend['2021']).str.rstrip('%')
dividend['2020'] = (dividend['2020']).str.rstrip('%')
dividend['2019'] = (dividend['2019']).str.rstrip('%')
dividend['2018'] = (dividend['2018']).str.rstrip('%')
dividend['2017'] = (dividend['2017']).str.rstrip('%')
dividend['2016'] = (dividend['2016']).str.rstrip('%')
dividend['2015'] = (dividend['2015']).str.rstrip('%')
dividend['2014'] = (dividend['2014']).str.rstrip('%')
dividend['2013'] = (dividend['2013']).str.rstrip('%')
dividend['2012'] = (dividend['2012']).str.rstrip('%')
dividend['2011'] = (dividend['2011']).str.rstrip('%')

os.remove("dividend.csv")
dividend.to_csv("dividend.csv")
dividend = pd.read_csv("dividend.csv", sep=',', decimal=',', thousands='.', encoding='ISO-8859-1' )

dividend.rename(columns={dividend.columns[0]: "tickers" }, inplace=True)
dividend.fillna(value=0, inplace=True)

dividend = dividend.loc[dividend['DY'] > 0].loc[
    dividend['2022'] > 0].loc[
    dividend['2021'] > 0].loc[
    dividend['2020'] > 0].loc[
    dividend['2019'] > 0]


dividend
# Out:
#     tickers     DY   2022  2021   2020  2019  2018   2017   2016   2015  \
# 1     ABCB4   8.43   9.48  7.90   1.01  5.20  6.39   6.32   7.80  13.72
# 2     ABEV3   5.46   5.25  4.41   2.64  2.63  3.58   2.54   3.90   4.01
# 6     AFLT3   2.95   2.55  7.10   7.33  0.95  3.25  13.97  14.17   0.00
# 7     AGRO3  12.49  17.54  9.10   2.84  4.89  4.88   1.93   5.29  12.67
# 18   ALUP11   5.85   4.36  3.49   2.55  1.63  3.93   2.78   4.91   9.13
# ..      ...    ...    ...   ...    ...   ...   ...    ...    ...    ...
# 613   WHRL3   3.99   3.91  8.75  16.57  5.24  3.15  10.88   0.00   4.84
# 614   WHRL4   4.48   4.12  8.07  16.35  6.62  2.92  11.15   0.00   5.89
# 615   WIZC3   7.20   8.39  7.65   8.32  7.87  7.30   6.04   6.51   0.00
# 616   WLMM3   3.14   5.66  1.68   1.45  1.46  0.00   0.00   0.00   0.00
# 617   WLMM4   2.32   3.32  1.58   1.11  1.57  0.00   0.00   0.00   0.00
#
#       2014  2013  2012  2011
# 1     4.88  4.78  2.34  4.81
# 2     4.67  0.00  0.00  0.00
# 6     7.77  4.08  0.00  0.00
# 7     0.00  1.07  0.00  0.00
# 18   12.24  0.00  0.00  0.00
# ..     ...   ...   ...   ...
# 613  17.95  9.01  6.51  5.38
# 614  19.99  9.27  6.85  5.13
# 615   0.00  0.00  0.00  0.00
# 616   0.00  0.00  0.00  0.00
# 617   0.00  0.00  0.00  0.00
#
# [189 rows x 14 columns]

# %% [markdown]
# Preço / Lucro por ação - PL

# %%
dy = dividend['tickers'].tolist()
len(dy)
# Out:
# 189

# %%
# dicionario com todas as ações por linha a serem substituidas
index_stocks = []
index_tickers = {}
for i, v in zip((range(len(dy))), dy):
    index_tickers[i] = v
    index_stocks.append(index_tickers)
#index_tickers

url = 'https://statusinvest.com.br/acoes/busca-avancada'

pls = []

url = 'https://statusinvest.com.br/acoes/'

for i, v in zip(dy, (range(len(dy)))):
    print(f'{v}.{i}') 

    headers = {
        'authority': 'statusinvest.com.br',
        'sec-ch-ua': '\"Google Chrome\";v=\"116\", \"Chromium\";v=\"116\", \";Not A Brand\";v=\"99\"',
        'accept': '*/*',
        'x-requested-with': 'XMLHttpRequest',
        'sec-ch-ua-mobile': '?0',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36',
        'content-type': 'application/x-www-form-urlencoded; charset=UTF-8',
        'origin': 'https://statusinvest.com.br',
        'sec-fetch-site': 'same-origin',
        'sec-fetch-mode': 'cors',
        'sec-fetch-dest': 'empty',
        'referer': url + str(i),
        'accept-language': 'pt-BR,pt;q=0.9,en-US;q=0.8,en;q=0.7',
        'cookie': '_adasys=e2299e4d-38b0-48c7-91be-a844fb91e62c; _ga=GA1.3.1768435062.1608297004; G_ENABLED_IDPS=google; __cfduid=d96cf593e372b319fd9ac85a0385fd3971614276176; denakop_freq={}; _gid=GA1.3.490929924.1615153324; __cf_bm=ccb5439cbc002734ed38f28e7c99677ec0b5afff-1615325452-1800-AWbw2mlOXKHt6BZ0dybIWT1O8Z4S9u6Mv7pm7/qkTNvQPFa+jTjP1n06mQmPXqmE938CAjZonuuP2B6noCkuoBpP5ouTIc/MWeUoxtuhdKfJ05v24zpwzU/CpAosevhANA==; _gat_gtag_UA_142136095_1=1',
    }   

    data = {
        'ticker': str(i),
        'time': '5'
    }

    response = requests.post('https://statusinvest.com.br/acao/indicatorhistorical', headers=headers, data=data)

    
    try:
        r = response.json()
    except json.JSONDecodeError as e:
        print(f"Error decoding JSON: {e}")
        exit(1)
    

    # Coletando informações para DataFrame
    pl = {}
    
    
    c = requests.get(url + str(i)).content
    soup = BeautifulSoup(c)


       ### INDICADORES DE VALUATION ###

    try:    
        pl['P/L'] = r['data'][1]['ranks'][0]['value_F']
    except:
        pl['P/L'] = np.NaN
    try:    
        pl['2022'] = r['data'][1]['ranks'][1]['value_F']
    except:
        pl['2022'] = np.NaN
    try:    
        pl['2021'] = r['data'][1]['ranks'][2]['value_F']
    except:
        pl['2021'] = np.NaN
    try:    
        pl['2020'] = r['data'][1]['ranks'][3]['value_F']
    except:
        pl['2020'] = np.NaN
    try:    
        pl['2019'] = r['data'][1]['ranks'][4]['value_F']
    except:
        pl['2019'] = np.NaN
    try:    
        pl['2018'] = r['data'][1]['ranks'][5]['value_F']
    except:
        pl['2018'] = np.NaN
    try:    
        pl['2017'] = r['data'][1]['ranks'][6]['value_F']
    except:
        pl['2017'] = np.NaN
    try:    
        pl['2016'] = r['data'][1]['ranks'][7]['value_F']
    except:
        pl['2016'] = np.NaN    
    try:    
        pl['2015'] = r['data'][1]['ranks'][8]['value_F']
    except:
        pl['2015'] = np.NaN
    try:    
        pl['2014'] = r['data'][1]['ranks'][9]['value_F']
    except:
        pl['2014'] = np.NaN
    try:    
        pl['2013'] = r['data'][1]['ranks'][10]['value_F']
    except:
        pl['2013'] = np.NaN
    try:    
        pl['2012'] = r['data'][1]['ranks'][11]['value_F']
    except:
        pl['2012'] = np.NaN    
    try:    
        pl['2011'] = r['data'][1]['ranks'][12]['value_F']
    except:
        pl['2011'] = np.NaN




    # Adicionando resultado a lista de cards
    pls.append(pl)
# Out:
# 0.ABCB4
# 1.ABEV3
# 2.AFLT3
# 3.AGRO3
# 4.ALUP11
# 5.ALUP3
# 6.ALUP4
# 7.ARZZ3
# 8.B3SA3
# 9.BAZA3
# 10.BBAS3
# 11.BBDC3
# 12.BBDC4
# 13.BBSE3
# 14.BEES3
# 15.BEES4
# 16.BGIP4
# 17.BMEB3
# 18.BMEB4
# 19.BMGB4
# 20.BMIN4
# 21.BMKS3
# 22.BNBR3
# 23.BPAC11
# 24.BPAC3
# 25.BPAC5
# 26.BPAN4
# 27.BRAP3
# 28.BRAP4
# 29.BRGE11
# 30.BRGE6
# 31.BRGE8
# 32.BRIV4
# 33.BRSR3
# 34.BRSR5
# 35.BRSR6
# 36.BSLI3
# 37.CAML3
# 38.CCRO3
# 39.CEBR3
# 40.CEBR5
# 41.CEBR6
# 42.CEEB3
# 43.CGAS3
# 44.CGAS5
# 45.CGRA3
# 46.CGRA4
# 47.CIEL3
# 48.CLSC3
# 49.CLSC4
# 50.CMIG3
# 51.CMIG4
# 52.COCE5
# 53.CPFE3
# 54.CPLE3
# 55.CPLE6
# 56.CRFB3
# 57.CRIV4
# 58.CRPG5
# 59.CRPG6
# 60.CSAB4
# 61.CSAN3
# 62.CSMG3
# 63.CSNA3
# 64.CSRN3
# 65.CSUD3
# 66.CYRE3
# 67.DIRR3
# 68.DXCO3
# 69.EALT3
# 70.EALT4
# 71.EGIE3
# 72.EKTR3
# 73.EKTR4
# 74.ELET3
# 75.ELET6
# 76.EMAE4
# 77.ENAT3
# 78.ENBR3
# 79.ENGI11
# 80.ENGI3
# 81.ENGI4
# 82.ENMT4
# 83.EQPA3
# 84.EQPA5
# 85.EQPA7
# 86.EQTL3
# 87.EZTC3
# 88.FESA3
# 89.FESA4
# 90.FLRY3
# 91.FRAS3
# 92.GEPA3
# 93.GEPA4
# 94.GGBR3
# 95.GGBR4
# 96.GOAU3
# 97.GOAU4
# 98.GRND3
# 99.GUAR3
# 100.HBTS5
# 101.HYPE3
# 102.IGTI3
# 103.ITSA3
# 104.ITSA4
# 105.ITUB3
# 106.ITUB4
# 107.JBSS3
# 108.JHSF3
# 109.JOPA3
# 110.JOPA4
# 111.KEPL3
# 112.KLBN11
# 113.KLBN3
# 114.KLBN4
# 115.LEVE3
# 116.LOGG3
# 117.LREN3
# 118.MDIA3
# 119.MERC4
# 120.MOAR3
# 121.MOVI3
# 122.MRVE3
# 123.MTSA4
# 124.MULT3
# 125.MYPK3
# 126.NEOE3
# 127.ODPV3
# 128.OFSA3
# 129.PARD3
# 130.PATI3
# 131.PEAB3
# 132.PEAB4
# 133.PETR3
# 134.PNVL3
# 135.POMO3
# 136.POMO4
# 137.PSSA3
# 138.PTBL3
# 139.QUAL3
# 140.RADL3
# 141.RANI3
# 142.RAPT3
# 143.RAPT4
# 144.REDE3
# 145.RENT3
# 146.ROMI3
# 147.RPAD5
# 148.SANB11
# 149.SANB3
# 150.SANB4
# 151.SAPR11
# 152.SAPR3
# 153.SAPR4
# 154.SBSP3
# 155.SHUL4
# 156.SIMH3
# 157.SLCE3
# 158.SMTO3
# 159.STBP3
# 160.SULA11
# 161.SULA3
# 162.SULA4
# 163.TAEE11
# 164.TAEE3
# 165.TAEE4
# 166.TGMA3
# 167.TIMS3
# 168.TOTS3
# 169.TRIS3
# 170.TRPL3
# 171.TRPL4
# 172.UCAS3
# 173.UGPA3
# 174.UNIP3
# 175.UNIP5
# 176.UNIP6
# 177.USIM3
# 178.USIM5
# 179.USIM6
# 180.VALE3
# 181.VBBR3
# 182.VIVT3
# 183.WEGE3
# 184.WHRL3
# 185.WHRL4
# 186.WIZC3
# 187.WLMM3
# 188.WLMM4

# %%
# Criando um DataFrame com os resultados
p_l = pd.DataFrame(pls)
p_l.rename(index = index_tickers, inplace = True)
p_l = p_l.replace('-', '')
p_l.to_csv('pl.csv')

# %%
p_l = pd.read_csv("pl.csv", sep=',', decimal=',', thousands='.', encoding='ISO-8859-1' )
p_l.rename(columns={p_l.columns[0]: "tickers" }, inplace=True)
p_l.fillna(value=0, inplace=True)
p_l
# Out:
#     tickers    P/L   2022   2021   2020   2019   2018   2017   2016   2015  \
# 0     ABCB4   5.35   5.62   6.37  10.16   8.86   8.25   7.64   6.19   3.57
# 1     ABEV3  15.39  15.82  19.16  21.64  24.93  21.99  46.01  20.54  22.58
# 2     AFLT3  14.33  15.60   5.61  33.25  27.67  15.48  25.05  13.33   0.00
# 3     AGRO3   9.88   6.75   5.67   4.89   9.05   5.01   5.77  23.02   0.00
# 4    ALUP11  11.52   9.01   6.33   8.43   9.08  13.89  13.96  13.77  13.10
# ..      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 184   WHRL3  20.04  17.24  10.29  15.44   8.44  35.78  16.03  14.51  13.62
# 185   WHRL4  19.61  18.03  12.26  17.21   8.68  42.44  17.20  15.38  12.31
# 186   WIZC3   9.41   8.32   6.77   6.60  10.56   6.31  11.76  14.84   0.00
# 187   WLMM3   8.08   6.67  11.71  14.73   9.49  11.33 -40.37   0.00   0.00
# 188   WLMM4  12.04   7.05  13.72  21.22   9.71  11.48 -28.64   0.00   0.00
#
#       2014   2013   2012   2011
# 0     6.21   6.85   7.95   7.18
# 1    21.24   0.00   0.00   0.00
# 2    13.60  11.36  10.70  14.70
# 3     0.00   0.00   0.00   0.00
# 4    10.13   3.06   0.00   0.00
# ..     ...    ...    ...    ...
# 184   8.48   7.19   7.86  12.41
# 185   8.37   7.69   8.20  14.31
# 186   0.00   0.00   0.00   0.00
# 187   0.00   0.00   0.00   0.00
# 188   0.00   0.00   0.00   0.00
#
# [189 rows x 14 columns]

# %%
p_l = p_l.loc[p_l['P/L'] > 0.01].loc[p_l['P/L'] <= 15].loc[
    p_l['2022'] > 0.01].loc[p_l['2022'] <= 15].loc[
    p_l['2021'] > 0.01].loc[p_l['2021'] <= 15].loc[
    p_l['2020'] > 0.01].loc[p_l['2020'] <= 15].loc[
    p_l['2019'] > 0.01].loc[p_l['2019'] <= 15]

p_l
# Out:
#     tickers    P/L  2022   2021   2020   2019   2018   2017   2016   2015  \
# 0     ABCB4   5.35  5.62   6.37  10.16   8.86   8.25   7.64   6.19   3.57
# 3     AGRO3   9.88  6.75   5.67   4.89   9.05   5.01   5.77  23.02   0.00
# 4    ALUP11  11.52  9.01   6.33   8.43   9.08  13.89  13.96  13.77  13.10
# 5     ALUP3  11.54  8.77   6.38   8.36  11.26  17.05  18.11  19.62   0.00
# 6     ALUP4  11.48  9.14   6.34   8.31   8.34  12.41  12.14  10.63   0.00
# ..      ...    ...   ...    ...    ...    ...    ...    ...    ...    ...
# 165   TAEE4  10.05  8.31   5.69   5.11  10.83   7.33  10.84   0.00   0.00
# 170   TRPL3   8.77  8.43   6.68   5.75  10.29   6.03   7.09   1.93  13.74
# 171   TRPL4   6.73  6.70   5.31   5.45   8.44   6.06   8.07   2.12  14.61
# 186   WIZC3   9.41  8.32   6.77   6.60  10.56   6.31  11.76  14.84   0.00
# 187   WLMM3   8.08  6.67  11.71  14.73   9.49  11.33 -40.37   0.00   0.00
#
#       2014    2013  2012  2011
# 0     6.21    6.85  7.95  7.18
# 3     0.00    0.00  0.00  0.00
# 4    10.13    3.06  0.00  0.00
# 5     0.00    0.00  0.00  0.00
# 6     0.00    0.00  0.00  0.00
# ..     ...     ...   ...   ...
# 165   0.00    0.00  0.00  0.00
# 170   0.00    0.00  8.05  8.96
# 171  16.75  128.74  5.97  9.62
# 186   0.00    0.00  0.00  0.00
# 187   0.00    0.00  0.00  0.00
#
# [63 rows x 14 columns]

# %%
ROE

# %%
roe = p_l['tickers'].tolist()
len(roe)
# Out:
# 63

# %%
# dicionario com todas as ações por linha a serem substituidas
index_stocks = []
index_tickers = {}
for i, v in zip((range(len(roe))), roe):
    index_tickers[i] = v
    index_stocks.append(index_tickers)
#index_tickers

url = 'https://statusinvest.com.br/acoes/busca-avancada'

roes = []

url = 'https://statusinvest.com.br/acoes/'

for i, v in zip(roe, (range(len(roe)))):
    print(f'{v}.{i}') 

    headers = {
        'authority': 'statusinvest.com.br',
        'sec-ch-ua': '\"Google Chrome\";v=\"116\", \"Chromium\";v=\"116\", \";Not A Brand\";v=\"99\"',
        'accept': '*/*',
        'x-requested-with': 'XMLHttpRequest',
        'sec-ch-ua-mobile': '?0',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36',
        'content-type': 'application/x-www-form-urlencoded; charset=UTF-8',
        'origin': 'https://statusinvest.com.br',
        'sec-fetch-site': 'same-origin',
        'sec-fetch-mode': 'cors',
        'sec-fetch-dest': 'empty',
        'referer': url + str(i),
        'accept-language': 'pt-BR,pt;q=0.9,en-US;q=0.8,en;q=0.7',
        'cookie': '_adasys=e2299e4d-38b0-48c7-91be-a844fb91e62c; _ga=GA1.3.1768435062.1608297004; G_ENABLED_IDPS=google; __cfduid=d96cf593e372b319fd9ac85a0385fd3971614276176; denakop_freq={}; _gid=GA1.3.490929924.1615153324; __cf_bm=ccb5439cbc002734ed38f28e7c99677ec0b5afff-1615325452-1800-AWbw2mlOXKHt6BZ0dybIWT1O8Z4S9u6Mv7pm7/qkTNvQPFa+jTjP1n06mQmPXqmE938CAjZonuuP2B6noCkuoBpP5ouTIc/MWeUoxtuhdKfJ05v24zpwzU/CpAosevhANA==; _gat_gtag_UA_142136095_1=1',
    }   

    data = {
        'ticker': str(i),
        'time': '5'
    }

    response = requests.post('https://statusinvest.com.br/acao/indicatorhistorical', headers=headers, data=data)

    
    try:
        r = response.json()
    except json.JSONDecodeError as e:
        print(f"Error decoding JSON: {e}")
        exit(1)
    

    # Coletando informações para DataFrame
    roe = {}
    
    
    c = requests.get(url + str(i)).content
    soup = BeautifulSoup(c)


       ### INDICADORES DE VALUATION ###

    try:    
        roe['ROE'] = r['data'][24]['ranks'][0]['value_F']
    except:
        roe['ROE'] = np.NaN
    try:    
        roe['2022'] = r['data'][24]['ranks'][1]['value_F']
    except:
        roe['2022'] = np.NaN
    try:    
        roe['2021'] = r['data'][24]['ranks'][2]['value_F']
    except:
        roe['2021'] = np.NaN
    try:    
        roe['2020'] = r['data'][24]['ranks'][3]['value_F']
    except:
        roe['2020'] = np.NaN
    try:    
        roe['2019'] = r['data'][24]['ranks'][4]['value_F']
    except:
        roe['2019'] = np.NaN
    try:    
        roe['2018'] = r['data'][24]['ranks'][5]['value_F']
    except:
        roe['2018'] = np.NaN
    try:    
        roe['2017'] = r['data'][24]['ranks'][6]['value_F']
    except:
        roe['2017'] = np.NaN
    try:    
        roe['2016'] = r['data'][24]['ranks'][7]['value_F']
    except:
        roe['2016'] = np.NaN    
    try:    
        roe['2015'] = r['data'][24]['ranks'][8]['value_F']
    except:
        roe['2015'] = np.NaN
    try:    
        roe['2014'] = r['data'][24]['ranks'][9]['value_F']
    except:
        roe['2014'] = np.NaN
    try:    
        roe['2013'] = r['data'][24]['ranks'][10]['value_F']
    except:
        roe['2013'] = np.NaN
    try:    
        roe['2012'] = r['data'][24]['ranks'][11]['value_F']
    except:
        roe['2012'] = np.NaN    
    try:    
        roe['2011'] = r['data'][24]['ranks'][12]['value_F']
    except:
        roe['2011'] = np.NaN




    # Adicionando resultado a lista de cards
    roes.append(roe)
# Out:
# 0.ABCB4
# 1.AGRO3
# 2.ALUP11
# 3.ALUP3
# 4.ALUP4
# 5.BAZA3
# 6.BBAS3
# 7.BBDC3
# 8.BEES3
# 9.BEES4
# 10.BGIP4
# 11.BMEB3
# 12.BMEB4
# 13.BNBR3
# 14.BRIV4
# 15.BRSR3
# 16.BRSR5
# 17.BRSR6
# 18.CEBR3
# 19.CEBR5
# 20.CEBR6
# 21.CEEB3
# 22.CGRA3
# 23.CGRA4
# 24.CLSC3
# 25.CLSC4
# 26.CMIG3
# 27.CMIG4
# 28.CPFE3
# 29.CRPG5
# 30.CRPG6
# 31.CSMG3
# 32.CSRN3
# 33.EALT4
# 34.EKTR3
# 35.EKTR4
# 36.ENBR3
# 37.FRAS3
# 38.ITSA3
# 39.ITSA4
# 40.ITUB3
# 41.JBSS3
# 42.JHSF3
# 43.MTSA4
# 44.NEOE3
# 45.PSSA3
# 46.RAPT3
# 47.ROMI3
# 48.SANB11
# 49.SANB3
# 50.SANB4
# 51.SAPR11
# 52.SAPR3
# 53.SAPR4
# 54.SHUL4
# 55.SMTO3
# 56.TAEE11
# 57.TAEE3
# 58.TAEE4
# 59.TRPL3
# 60.TRPL4
# 61.WIZC3
# 62.WLMM3

# %%
# Criando um DataFrame com os resultados
roe = pd.DataFrame(roes)
roe.rename(index = index_tickers, inplace = True)

roe = roe.replace('-', '')
roe = roe.replace('-%', '')

roe['ROE'] = (roe['ROE']).str.rstrip('%')
roe['2022'] = (roe['2022']).str.rstrip('%')
roe['2021'] = (roe['2021']).str.rstrip('%')
roe['2020'] = (roe['2020']).str.rstrip('%')
roe['2019'] = (roe['2019']).str.rstrip('%')
roe['2018'] = (roe['2018']).str.rstrip('%')
roe['2017'] = (roe['2017']).str.rstrip('%')
roe['2016'] = (roe['2016']).str.rstrip('%')
roe['2015'] = (roe['2015']).str.rstrip('%')
roe['2014'] = (roe['2014']).str.rstrip('%')
roe['2013'] = (roe['2013']).str.rstrip('%')
roe['2012'] = (roe['2012']).str.rstrip('%')
roe['2011'] = (roe['2011']).str.rstrip('%')


roe.to_csv('roe.csv')

# %%
roe = pd.read_csv("roe.csv", sep=',', decimal=',', thousands='.', encoding='ISO-8859-1' )
roe.rename(columns={roe.columns[0]: "tickers" }, inplace=True)
roe.fillna(value=0, inplace=True)

roe = roe.loc[roe['ROE'] >= 6].loc[
    roe['2022'] >= 6].loc[
    roe['2021'] >= 6].loc[
    roe['2020'] >= 6].loc[
    roe['2019'] >= 6]

roe
# Out:
#    tickers    ROE   2022    2021   2020    2019    2018   2017    2016   2015  \
# 0    ABCB4  14.50  15.09   11.94   7.87   12.23   11.14  12.57   13.08  14.75
# 1    AGRO3  12.22  20.50   23.83  28.32   13.58   23.43  18.93    3.97   1.06
# 2   ALUP11  10.19  13.20   17.03  16.38   17.80    8.94   8.52   10.72   8.33
# 3    ALUP3  10.19  13.20   17.03  16.38   17.80    8.94   8.52   10.72   8.33
# 4    ALUP4  10.19  13.20   17.03  16.38   17.80    8.94   8.52   10.72   8.33
# 5    BAZA3  22.87  23.18   25.05  10.99   12.52    5.63   3.42    6.67  12.94
# 6    BBAS3  20.01  18.78   13.82  10.63   15.22   13.57  10.92    8.14  17.04
# 7    BBDC3   9.78  13.41   15.61  11.01   15.56   13.34  14.56   16.99  19.97
# 8    BEES3  16.14  17.36   12.57  13.15   13.54   10.44  12.06   11.52  13.27
# 9    BEES4  16.14  17.36   12.57  13.15   13.54   10.44  12.06   11.52  13.27
# 10   BGIP4  10.32  12.68   14.92  11.14   19.27   15.41  23.21   19.59   9.41
# 11   BMEB3  15.91  15.18   17.26  17.94   12.51    7.00   8.54    2.16  13.45
# 12   BMEB4  15.91  15.18   17.26  17.94   12.51    7.00   8.54    2.16  13.45
# 13   BNBR3  22.64  22.40   21.64  16.51   32.00   17.35  19.10   21.77  10.75
# 15   BRSR3   8.61   8.85   11.94   7.51   16.27   12.33  14.88   10.83  13.59
# 16   BRSR5   8.61   8.85   11.94   7.51   16.27   12.33  14.88   10.83  13.59
# 17   BRSR6   8.61   8.85   11.94   7.51   16.27   12.33  14.88   10.83  13.59
# 18   CEBR3  18.78  20.09  150.84  63.74   15.18   15.32  20.60   17.93   4.30
# 19   CEBR5  18.78  20.09  150.84  63.74   15.18   15.32  20.60   17.93   4.30
# 20   CEBR6  18.78  20.09  150.84  63.74   15.18   15.32  20.60   17.93   4.30
# 21   CEEB3  25.40  26.51   27.02  19.95   19.34   12.27   5.59    8.79  11.25
# 22   CGRA3  11.41  14.31   23.36  11.23   22.09   10.80  12.84   13.94  10.80
# 23   CGRA4  11.41  14.31   23.36  11.23   22.09   10.80  12.84   13.94  10.80
# 26   CMIG3  28.07  18.79   19.28  16.39   19.69   11.66   6.99    2.59  19.01
# 27   CMIG4  28.07  18.79   19.28  16.39   19.69   11.66   6.99    2.59  19.01
# 28   CPFE3  31.00  31.37   31.35  26.14   20.80   20.05  13.16    8.69  11.27
# 29   CRPG5  14.88   8.45   31.54  25.34   19.03   30.58  17.53   19.92  -6.12
# 30   CRPG6  14.88   8.45   31.54  25.34   19.03   30.58  17.53   19.92  -6.12
# 31   CSMG3  14.28  11.63    7.95  12.65   11.19    9.29   8.98    7.31  -0.21
# 32   CSRN3  38.87  41.35   35.23  25.73   25.96   25.00  22.09   20.26  21.83
# 33   EALT4  14.12  17.20   19.34  13.75   10.35    7.92  31.27   -2.39   0.17
# 34   EKTR3  30.29  34.42   25.42  19.85   18.56   18.06  18.44   17.60  18.91
# 35   EKTR4  30.29  34.42   25.42  19.85   18.56   18.06  18.44   17.60  18.91
# 36   ENBR3   8.82   9.52   19.37  14.90   14.50   14.93   7.76    8.86  21.78
# 38   ITSA3  17.26  18.78   18.52  12.30   18.67   17.11  15.30   17.20  19.77
# 39   ITSA4  17.26  18.78   18.52  12.30   18.67   17.11  15.30   17.20  19.77
# 40   ITUB3  17.65  17.68   17.51  13.21   19.80   18.21  17.18   17.65  22.93
# 41   JBSS3  10.97  33.35   46.43  11.46   20.48    0.10   2.20    0.98  16.55
# 42   JHSF3   9.21  12.65   22.48  17.17   10.69    8.18  -1.07  -11.90   4.11
# 43   MTSA4  22.64  23.95   16.84  20.50    7.45    7.08   5.98    6.35   8.18
# 44   NEOE3  16.86  17.64   16.43  13.27   11.75    8.90   2.64    3.48   3.51
# 45   PSSA3  16.29  10.72   16.49  18.83   16.68   17.15  14.27   13.08  15.51
# 46   RAPT3  16.22  17.19   27.69  32.46   14.63    9.93   3.26   -4.76  -1.93
# 47   ROMI3  20.09  19.67   21.15  21.46   17.12   12.07   5.87   -6.62   0.93
# 48  SANB11   8.92  13.01   14.27  15.81   16.98   13.83  10.30    8.72  12.32
# 49   SANB3   8.92  13.01   14.27  15.81   16.98   13.83  10.30    8.72  12.32
# 50   SANB4   8.92  13.01   14.27  15.81   16.98   13.83  10.30    8.72  12.32
# 51  SAPR11  15.03  13.11   15.05  14.35   17.49   15.61  13.32   13.04  10.49
# 52   SAPR3  15.03  13.11   15.05  14.35   17.49   15.61  13.32   13.04  10.49
# 53   SAPR4  15.03  13.11   15.05  14.35   17.49   15.61  13.32   13.04  10.49
# 54   SHUL4  26.54  24.22   21.21  19.10   15.67   12.99   8.23    6.71  10.99
# 55   SMTO3  17.16  19.10   37.15  27.70   18.84    9.55  14.45   10.72   7.91
# 56  TAEE11  17.46  22.06   33.12  37.55   20.33   23.43  14.91   20.01  20.78
# 57   TAEE3  17.46  22.06   33.12  37.55   20.33   23.43  14.91   20.01  20.78
# 58   TAEE4  17.46  22.06   33.12  37.55   20.33   23.43  14.91   20.01  20.78
# 59   TRPL3  13.53  13.98   20.96  24.44   14.94   17.00  12.43   48.75   9.15
# 60   TRPL4  13.53  13.98   20.96  24.44   14.94   17.00  12.43   48.75   9.15
# 61   WIZC3  25.32  35.59   59.94  68.46  114.35  105.18  98.44  125.26  87.61
# 62   WLMM3  17.35  18.86   19.51  11.78   11.85    4.14  -1.78   -4.49   0.89
#
#      2014   2013   2012   2011
# 0   14.37  13.45  13.88  15.30
# 1   30.97  -2.28   5.14  -0.98
# 2   14.79  11.29  13.49  12.43
# 3   14.79  11.29  13.49  12.43
# 4   14.79  11.29  13.49  12.43
# 5    6.80  11.23   8.39   4.06
# 6   14.49  14.26  16.26  19.91
# 7   18.64  17.24  15.87  18.53
# 8   13.29  11.67   8.38   9.57
# 9   13.29  11.67   8.38   9.57
# 10   2.50  20.87  34.13  39.79
# 11 -29.20   8.92  16.10  11.17
# 12 -29.20   8.92  16.10  11.17
# 13  22.19  11.85  30.57  13.51
# 15  10.69  14.04  16.35  20.38
# 16  10.69  14.04  16.35  20.38
# 17  10.69  14.04  16.35  20.38
# 18 -90.28 -31.01   9.34   4.98
# 19 -90.28 -31.01   9.34   4.98
# 20 -90.28 -31.01   9.34   4.98
# 21  17.22  20.18  24.98  32.66
# 22  14.86  14.16  11.89  12.20
# 23  14.86  14.16  11.89  12.20
# 26  27.80  24.56  35.47  20.57
# 27  27.80  24.56  35.47  20.57
# 28  13.67  13.35  17.06  21.92
# 29 -14.23   2.73  12.15   8.74
# 30 -14.23   2.73  12.15   8.74
# 31   5.75   7.87   9.65  10.25
# 32  25.06  23.32  23.79  30.16
# 33   9.21  13.35  12.20  15.69
# 34  19.77  15.77  17.43  35.98
# 35  19.77  15.77  17.43  35.98
# 36  15.20   8.22   7.69  10.69
# 38  20.17  17.20  15.10  16.20
# 39  20.17  17.20  15.10  16.20
# 40  21.72  19.73  16.65  17.97
# 41   8.45   4.19   3.49  -0.37
# 42   1.84  14.45  14.72  18.94
# 43  10.36  12.35  12.49  10.69
# 44   7.17   8.63   8.86  13.77
# 45  14.60  23.84  13.47  12.34
# 46  14.11  17.58   3.11  19.87
# 47   1.13   0.21  -5.98   0.53
# 48   7.19   7.03   6.74   9.92
# 49   7.19   7.03   6.74   9.92
# 50   7.19   7.03   6.74   9.92
# 51  11.09  11.30  13.82  12.30
# 52  11.09  11.30  13.82  12.30
# 53  11.09  11.30  13.82  12.30
# 54  13.56  17.14  14.57  17.39
# 55  13.78   6.43   3.60   6.48
# 56  21.42  20.74  14.38  21.99
# 57  21.42  20.74  14.38  21.99
# 58  21.42  20.74  14.38  21.99
# 59   7.32   0.65  16.61  20.16
# 60   7.32   0.65  16.61  20.16
# 61  85.82  47.09  66.43   0.00
# 62   2.52   4.04   7.04   8.21
